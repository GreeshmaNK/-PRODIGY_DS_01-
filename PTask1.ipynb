# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('D:/exam/High_Value_Dataset__January_2024.csv')
df.head()
# Out:
#    SID Number  TDCJ Number                     Name    Current Facility  \
# 0      671628      2394062    ONOFRE,JESSE TINAJERO            Connally
# 1      686567       311644  PALACIOS,ROBERT LEONARD          Jester III
# 2      770626       449674            FLORES,ISABEL                Pack
# 3      771601      1491019        MOLETT,JOHN HENRY            W. Scott
# 4      799447       248098       DOWDEN,BILLY WAYNE  Hospital Galveston
#
#   Gender      Race  Age Projected Release Maximum Sentence Date  \
# 0      M  Hispanic   88         4/23/2026             4/23/2026
# 1      M  Hispanic   85         9/12/2028             5/12/2036
# 2      M  Hispanic   86          1/1/9999              1/1/9999
# 3      M     Black   81         12/2/2037             12/2/2037
# 4      M     White   87          1/1/9999              1/1/9999
#
#   Parole Eligibility Date  Case Number  County  Offense Code  \
# 0               4/22/2024   2019CR4680   Bexar      36010001
# 1               4/15/2022       320670  Harris      22100000
# 2                9/2/2006  86CR-1234-B  Nueces       9150000
# 3               12/2/2022      1144294  Harris      12990002
# 4               5/24/1981       225031  Harris       9130000
#
#                 TDCJ Offense Sentence Date Offense Date Sentence (Years)  \
# 0      INDEC W/CHILD CONTACT     5/16/2022     8/2/2016                4
# 1  BURG HAB W/I SEXUAL ABUSE    10/21/1980    1/28/1980               30
# 2        MURDER W/DEADLY WPN     4/13/1987     9/2/1986             Life
# 3           AGG ROBBERY W/DW     2/21/2008    12/3/2007               30
# 4             CAPITAL MURDER     4/30/1975    6/28/1974     Capital Life
#
#    Last Parole Decision Next Parole Review Date      Parole Review Status
# 0                   NaN               4/22/2024  IN PAROLE REVIEW PROCESS
# 1  Denied on 05/01/2023                  26-Apr     NOT IN REVIEW PROCESS
# 2  Denied on 07/21/2021                  24-Jul     NOT IN REVIEW PROCESS
# 3  Denied on 01/24/2024                  25-Jan     NOT IN REVIEW PROCESS
# 4  Denied on 11/20/2021                  24-Nov     NOT IN REVIEW PROCESS

# %%
race_counts = df['Race'].value_counts()
plt.figure(figsize=(10, 6))
race_counts.plot(kind='bar', color='skyblue')
plt.title('Race Distribution')
plt.xlabel('Race')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Age'], bins=10, color='green', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
